# %% [markdown]
# # Ray UI
#
# Start the UI with **Kernel -> Restart and Run All**.

# %%
import os
import ray
import ray.experimental.ui as ui

ray.init(redis_address=os.environ["REDIS_ADDRESS"])
# Out:
# {'local_scheduler_socket_names': ['/tmp/scheduler50609544'],
#  'node_ip_address': '192.168.12.3',
#  'object_store_addresses': [ObjectStoreAddress(name='/tmp/plasma_store64011500', manager_name='/tmp/plasma_manager69842588', manager_port=26751)],
#  'redis_address': '192.168.12.3:6349',
#  'webui_url': None}

# %%
import time

@ray.remote
def slow_function(i):
	"""This function is a proxy for a more interesting and computationally
	intensive function.
	"""
	time.sleep(1)
	return i


def measure_duration():
	"""Sleep a little to improve the accuracy of the timing measurements below.
	We do this because workers may still be starting up in the background.
	"""
	time.sleep(2.0)
	start_time = time.time()
	
	results = ray.get([slow_function.remote(i) for i in range(4)])
	
	end_time = time.time()
	duration = end_time - start_time
	return results, duration


# EXERCISE:
print(slow_function.remote(0))
print(ray.get(slow_function.remote(0)))

# EXERCISE:
results, duration = measure_duration()
assert results == [0, 1, 2, 3], 'Did you remember to call ray.get?'
assert duration < 1.1, ('The loop took {} seconds. This is too slow.'
                                                .format(duration))
assert duration > 1, ('The loop took {} seconds. This is too fast.'
                                            .format(duration))
print('Success! The example took {} seconds.'.format(duration))
# Out:
# ObjectID(d75c85703ff1715700b686c3ede95dc2278b1ab5)
# 0
# Success! The example took 1.0031607151031494 seconds.

# %% [markdown]
# #### Object search.

# %%
ui.object_search_bar()
# Out:
# Text(value='', description='Search for an object:', placeholder='Object ID')
# {'DataSize': 524,
#  'Hash': '65aef164389659780000000014000000d75c85703ff1715700b686c3ede95dc2',
#  'IsPut': False,
#  'ManagerIDs': ['a6831272597df266c56d6c7dbd21e81f2d153509'],
#  'TaskID': 'd65c85703ff1715700b686c3ede95dc2278b1ab5'}

# %% [markdown]
# #### Task search.

# %% [markdown]
# #### Task trace timeline.

# %% [markdown]
# To view arrows, go to View Options and select Flow Events.

# %%
# ui.task_timeline()

# %% [markdown]
# ![](./assets/01.png)

# %% [markdown]
# #### Task durations.

# %%
ui.task_completion_time_distribution()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="20099f8a-f820-4dca-8644-4edf0beb6924">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="c8f6a4d7-834c-4050-aa34-16e87ce77d00"></div>
# </div>
# /home/reon/.anaconda3/lib/python3.6/site-packages/bokeh/core/json_encoder.py:80: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(type(obj), np.float):
# Dropdown(description='Selection Options:', index=1, options=('% total time', '% total tasks'), value='% total tasks')
# HBox(children=(IntRangeSlider(value=(0, 100), continuous_update=False, description='%:'), VBox(children=(FloatText(value=0.0, description='Start Time:', disabled=True), FloatText(value=0.0, description='End Time:', disabled=True)), layout=Layout(display='none')), IntText(value=-8, description='Num Tasks:')))

# %% [markdown]
# #### CPU usage.

# %%
ui.cpu_usage()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="557d19ca-fbaa-4a3d-bc79-34faa30c3dd0">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="16ea49ad-2a50-426d-82bd-b9c26e29ea61"></div>
# </div>
# Dropdown(description='Selection Options:', index=1, options=('% total time', '% total tasks'), value='% total tasks')
# HBox(children=(IntRangeSlider(value=(0, 100), continuous_update=False, description='%:'), VBox(children=(FloatText(value=0.0, description='Start Time:', disabled=True), FloatText(value=0.0, description='End Time:', disabled=True)), layout=Layout(display='none')), IntText(value=-8, description='Num Tasks:')))

# %% [markdown]
# #### Cluster usage.

# %%
ui.cluster_usage()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0ff1f4f2-094a-4986-832a-dda31292feb2">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="2f8dd46a-2d29-481b-8a2d-115fd20c5805"></div>
# </div>
# Dropdown(description='Selection Options:', index=1, options=('% total time', '% total tasks'), value='% total tasks')
# HBox(children=(IntRangeSlider(value=(0, 100), continuous_update=False, description='%:'), VBox(children=(FloatText(value=0.0, description='Start Time:', disabled=True), FloatText(value=0.0, description='End Time:', disabled=True)), layout=Layout(display='none')), IntText(value=-8, description='Num Tasks:')))
